# %%
import numpy as np 
import pandas as pd 

# !conda install -c conda-forge lxml --yes
print("Libraries installed.")
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                       \                                  -failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='1_73_pypy|3_73_pypy|4_73_pypy|2_73_pypy|0_73_pypy']
# ...

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_districts_in_Budapest')[1]

# %%
df
# Out:
#           District                                               Name  \
# 0       I. kerület                     Várkerület ("Castle District")
# 1      II. kerület                                                  -
# 2     III. kerület         Óbuda-Békásmegyer ("Old Buda-Békásmegyer")
# 3      IV. kerület                                Újpest ("New Pest")
# 4       V. kerület  Belváros-Lipótváros ("Inner City - Leopold Town")
# 5      VI. kerület                        Terézváros ("Theresa Town")
# 6     VII. kerület                   Erzsébetváros ("Elisabeth Town")
# 7    VIII. kerület                        Józsefváros ("Joseph Town")
# 8      IX. kerület                       Ferencváros ("Francis Town")
# 9       X. kerület                                 Kőbánya ("Quarry")
# 10     XI. kerület                                Újbuda ("New Buda")
# 11    XII. kerület                            Hegyvidék ("Highlands")
# ...

# %%
df.drop("Population density (people per km2)", axis=1, inplace=True)

# %%
df.drop("Population (2016)", axis=1, inplace=True)

# %%
df.drop("Area (km2)", axis=1, inplace=True)

# %%
df["Name"]=df["Name"]

# %%
df.head(23)
# Out:
#           District                                               Name
# 0       I. kerület                     Várkerület ("Castle District")
# 1      II. kerület                                                  -
# 2     III. kerület         Óbuda-Békásmegyer ("Old Buda-Békásmegyer")
# 3      IV. kerület                                Újpest ("New Pest")
# 4       V. kerület  Belváros-Lipótváros ("Inner City - Leopold Town")
# 5      VI. kerület                        Terézváros ("Theresa Town")
# 6     VII. kerület                   Erzsébetváros ("Elisabeth Town")
# 7    VIII. kerület                        Józsefváros ("Joseph Town")
# 8      IX. kerület                       Ferencváros ("Francis Town")
# 9       X. kerület                                 Kőbánya ("Quarry")
# 10     XI. kerület                                Újbuda ("New Buda")
# 11    XII. kerület                            Hegyvidék ("Highlands")
# ...

# %%
df.drop([1], inplace=True)

# %%
df.drop([15], inplace=True)

# %%
df
# Out:
#           District                                               Name
# 0       I. kerület                     Várkerület ("Castle District")
# 2     III. kerület         Óbuda-Békásmegyer ("Old Buda-Békásmegyer")
# 3      IV. kerület                                Újpest ("New Pest")
# 4       V. kerület  Belváros-Lipótváros ("Inner City - Leopold Town")
# 5      VI. kerület                        Terézváros ("Theresa Town")
# 6     VII. kerület                   Erzsébetváros ("Elisabeth Town")
# 7    VIII. kerület                        Józsefváros ("Joseph Town")
# 8      IX. kerület                       Ferencváros ("Francis Town")
# 9       X. kerület                                 Kőbánya ("Quarry")
# 10     XI. kerület                                Újbuda ("New Buda")
# 11    XII. kerület                            Hegyvidék ("Highlands")
# 12   XIII. kerület  Angyalföld-Újlipótváros-Vizafogó ("Angel's Fie...
# ...

# %%
df.shape
# Out:
# (22, 2)

# %%
# !conda install -c conda-forge geopy --yes
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                                          \failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='1_73_pypy|2_73_pypy|3_73_pypy|4_73_pypy|0_73_pypy']
# ...

# %%
from geopy.geocoders import Nominatim 
geolocator = Nominatim(user_agent="Cologne_food")

df['Major_Dist_Coord']= df['District'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
df[['Latitude', 'Longitude']] = df['Major_Dist_Coord'].apply(pd.Series)

df.drop(['Major_Dist_Coord'], axis=1, inplace=True)
df
# Out:
#           District                                               Name  \
# 0       I. kerület                     Várkerület ("Castle District")
# 2     III. kerület         Óbuda-Békásmegyer ("Old Buda-Békásmegyer")
# 3      IV. kerület                                Újpest ("New Pest")
# 4       V. kerület  Belváros-Lipótváros ("Inner City - Leopold Town")
# 5      VI. kerület                        Terézváros ("Theresa Town")
# 6     VII. kerület                   Erzsébetváros ("Elisabeth Town")
# 7    VIII. kerület                        Józsefváros ("Joseph Town")
# 8      IX. kerület                       Ferencváros ("Francis Town")
# 9       X. kerület                                 Kőbánya ("Quarry")
# 10     XI. kerület                                Újbuda ("New Buda")
# 11    XII. kerület                            Hegyvidék ("Highlands")
# 12   XIII. kerület  Angyalföld-Újlipótváros-Vizafogó ("Angel's Fie...
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json 

import requests 
from pandas.io.json import json_normalize 


import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 

print('Libraries imported.')
# Out:
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# ...
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                       |failed
#
# UnsatisfiableError: The following specifications were found
# to be incompatible with the existing python installation in your environment:
#
# Specifications:
#
#   - cffi -> python[version='2.7.*|3.5.*|3.6.*|3.6.12|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.9,<3.10.0a0|>=3.8,<3.9.0a0|3.6.9|3.6.9|3.6.9|>=2.7,<2.8.0a0|3.6.9|>=3.5,<3.6.0a0|3.4.*',build='4_73_pypy|3_73_pypy|2_73_pypy|1_73_pypy|0_73_pypy']
#   - rsa -> python[version='2.7.*|3.4.*|3.5.*|3.6.*']
#
# Your python: python=3.7
#
# If python is on the left-most side of the chain, that's the version you've asked for.
# ...

# %%
# !pip install beautifulsoup4
# !pip install lxml
import requests 
import pandas as pd 
import numpy as np 
import random 


from geopy.geocoders import Nominatim 


from IPython.display import Image 
from IPython.core.display import HTML 


from IPython.display import display_html
import pandas as pd
import numpy as np
    
from pandas.io.json import json_normalize


from bs4 import BeautifulSoup
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
# !pip install folium

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Folium installed
# Libraries imported.

# %%
address = 'Budapest'

geolocator = Nominatim(user_agent="Budapest_food")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Budapest are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Budapest are 47.48138955, 19.14607278448202.

# %%
import folium  
import pandas as pd

# %%
map_budapest = folium.Map(location=[latitude, longitude], zoom_start=11)



    
map_budapest

# %%
map_budapest = folium.Map(location=[latitude, longitude], zoom_start=11)

for lat, lng, label in zip(df['Latitude'], df['Longitude'], df['District']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_budapest) 
    
map_budapest
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'FNOZTCGGY3X3ARLEIE51OFMAXSSPCIGVJHQUU1V14EXZROVF' 
CLIENT_SECRET = 'T35AH1CZGE014ZHQKFZ3A2PNGUHILEAATZCPRA3QWUFUEUOI' 
VERSION = '20180604'
LIMIT = 100

# %%
df.loc[0, 'District']
# Out:
# 'I. kerület'

# %%
district_latitude = df.loc[0, 'Latitude'] 
district_longitude = df.loc[0, 'Longitude'] 

district_name = df.loc[0, 'District'] 

print('Latitude and longitude values of {} are {}, {}.'.format(district_name, 
                                                               district_latitude, 
                                                               district_longitude))
# Out:
# Latitude and longitude values of I. kerület are 47.4991627, 19.0351431.

# %%
LIMIT = 20

radius = 800

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=FNOZTCGGY3X3ARLEIE51OFMAXSSPCIGVJHQUU1V14EXZROVF&client_secret=T35AH1CZGE014ZHQKFZ3A2PNGUHILEAATZCPRA3QWUFUEUOI&v=20180604&ll=47.4991627,19.0351431&radius=800&limit=20'

# %%
results = requests.get(url).json()

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON


filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)


nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                                                 name      categories  \
# 0                                           Dísz tér           Plaza
# 1                                    Stand25 Bisztró          Bistro
# 2                                     Budavári Mikve   Historic Site
# 3  Halászbástya | Fisherman's Bastion (Halászbástya)   Historic Site
# 4                                          Várnegyed  Scenic Lookout
#
#          lat        lng
# 0  47.499100  19.036163
# 1  47.497673  19.032679
# 2  47.498546  19.035846
# 3  47.502029  19.035058
# 4  47.501195  19.032261

# %%
print('{} venues were found by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 20 venues were found by Foursquare.

# %%
print ('{}  categories in I. kerület.'.format(nearby_venues['categories'].value_counts().shape[0]))
# Out:
# 17  categories in I. kerület.

# %%
print (nearby_venues['categories'].value_counts()[0:15])
# Out:
# Historic Site           2
# Bistro                  2
# Scenic Lookout          2
# Indie Movie Theater     1
# Coffee Shop             1
# Chocolate Shop          1
# Plaza                   1
# Playground              1
# Castle                  1
# Hungarian Restaurant    1
# Bed & Breakfast         1
# History Museum          1
# Pub                     1
# French Restaurant       1
# Motorcycle Shop         1
# Name: categories, dtype: int64

# %%
              def getNearbyVenues(names, latitudes, longitudes, radius=3000, LIMIT=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['District', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']

    
    return(nearby_venues)

# %%
Budapest_venues = getNearbyVenues(names=df['District'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# I. kerület
# III. kerület
# IV. kerület
# V. kerület
# VI. kerület
# VII. kerület
# VIII. kerület
# IX. kerület
# X. kerület
# XI. kerület
# XII. kerület
# XIII. kerület
# XIV. kerület
# XV. kerület
# XVII. kerület
# XVIII. kerület
# XIX. kerület
# XX. kerület
# XXI. kerület
# XXII. kerület
# XXIII. kerület
# All

# %%
Budapest_venues.shape
# Out:
# (1839, 7)

# %%
Budapest_Venues_only_restaurant = Budapest_venues[Budapest_venues['Venue Category'].str.contains('Restaurant')].reset_index(drop=True)
Budapest_Venues_only_restaurant.index = np.arange(1, len(Budapest_Venues_only_restaurant )+1)

# %%
print (Budapest_Venues_only_restaurant['Venue Category'].value_counts())
# Out:
# Restaurant                       44
# Hungarian Restaurant             31
# Italian Restaurant               25
# Fast Food Restaurant             23
# Eastern European Restaurant      18
# Vietnamese Restaurant            13
# Asian Restaurant                 11
# Chinese Restaurant                9
# Greek Restaurant                  9
# Thai Restaurant                   8
# Mediterranean Restaurant          7
# Vegetarian / Vegan Restaurant     6
# Sushi Restaurant                  6
# Indian Restaurant                 5
# Mexican Restaurant                5
# Falafel Restaurant                3
# American Restaurant               3
# Spanish Restaurant                3
# Turkish Restaurant                3
# Tapas Restaurant                  3
# Scandinavian Restaurant           3
# Modern European Restaurant        2
# French Restaurant                 2
# Dim Sum Restaurant                2
# Jewish Restaurant                 2
# Dumpling Restaurant               2
# ...

# %%
print('There are {} unique categories.'.format(len(Budapest_Venues_only_restaurant['Venue Category'].unique())))
# Out:
# There are 34 unique categories.

# %%
Budapest_Venues_Top10 = Budapest_Venues_only_restaurant['Venue Category'].value_counts()[0:10].to_frame(name='frequency')
Budapest_Venues_Top10=Budapest_Venues_Top10.reset_index()
Budapest_Venues_Top10.rename(index=str, columns={"index": "Venue_Category", "frequency": "Frequency"}, inplace=True)
Budapest_Venues_Top10
# Out:
#                 Venue_Category  Frequency
# 0                   Restaurant         44
# 1         Hungarian Restaurant         31
# 2           Italian Restaurant         25
# 3         Fast Food Restaurant         23
# 4  Eastern European Restaurant         18
# 5        Vietnamese Restaurant         13
# 6             Asian Restaurant         11
# 7           Chinese Restaurant          9
# 8             Greek Restaurant          9
# 9              Thai Restaurant          8

# %%
import seaborn as sns
from matplotlib import pyplot as plt

s=sns.barplot(x="Venue_Category", y="Frequency", data=Budapest_Venues_Top10)
s.set_xticklabels(s.get_xticklabels(), rotation=45, horizontalalignment='right')

plt.title('10 Most Frequently Occuring Venues in 23 districts of Budapest', fontsize=15)
plt.xlabel("Venue Category", fontsize=16)
plt.ylabel ("Frequency", fontsize=16)
plt.savefig("Most_Freq_Venues1.png", dpi=300)
fig = plt.figure(figsize=(18,7))
plt.show()

# %%
print ("Shape of the Data-Frame with Venue Category only Restaurant: ", Budapest_Venues_only_restaurant.shape)
Budapest_Venues_only_restaurant.head(75)
# Out:
# Shape of the Data-Frame with Venue Category only Restaurant:  (257, 7)
#         District  District Latitude  District Longitude  \
# 1     I. kerület          47.499163           19.035143
# 2     I. kerület          47.499163           19.035143
# 3     I. kerület          47.499163           19.035143
# 4     I. kerület          47.499163           19.035143
# 5     I. kerület          47.499163           19.035143
# 6     I. kerület          47.499163           19.035143
# 7     I. kerület          47.499163           19.035143
# 8     I. kerület          47.499163           19.035143
# 9     I. kerület          47.499163           19.035143
# 10    I. kerület          47.499163           19.035143
# 11    I. kerület          47.499163           19.035143
# 12    I. kerület          47.499163           19.035143
# 13    I. kerület          47.499163           19.035143
# 14  III. kerület          47.567611           19.036780
# ...

# %%
Budapest_Venues_restaurant = Budapest_Venues_only_restaurant.groupby(['District'])['Venue Category'].apply(lambda x: x[x.str.contains('Restaurant')].count())

# %%
Budapest_Venues_restaurant
# Out:
# District
# All                2
# I. kerület        13
# III. kerület      20
# IV. kerület       17
# IX. kerület        9
# V. kerület        18
# VI. kerület       17
# VII. kerület      18
# VIII. kerület     19
# X. kerület        13
# XI. kerület       15
# XII. kerület       6
# XIII. kerület     12
# XIV. kerület      10
# XIX. kerület      19
# XV. kerület       10
# XVII. kerület      4
# XVIII. kerület    10
# XX. kerület        5
# XXI. kerület       9
# XXII. kerület      9
# XXIII. kerület     2
# Name: Venue Category, dtype: int64

# %%
Budapest_Venues_restaurant_df  = Budapest_Venues_restaurant.to_frame().reset_index()
Budapest_Venues_restaurant_df.columns = ['District', 'Number of Restaurant']
Budapest_Venues_restaurant_df.index = np.arange(1, len(Budapest_Venues_restaurant_df)+1)
list_rest_no =Budapest_Venues_restaurant_df['Number of Restaurant'].to_list()
list_dist =Budapest_Venues_restaurant_df['District'].to_list()

# %%
Budapest_onehot = pd.get_dummies(Budapest_Venues_only_restaurant[['Venue Category']], prefix="", prefix_sep="")

Budapest_onehot['District'] = Budapest_Venues_only_restaurant['District'] 

fixed_columns = [Budapest_onehot.columns[-1]] + list(Budapest_onehot.columns[:-1])
Budapest_onehot = Budapest_onehot[fixed_columns]

Budapest_onehot.head()
# Out:
#      District  Afghan Restaurant  American Restaurant  Asian Restaurant  \
# 1  I. kerület                  0                    0                 0
# 2  I. kerület                  0                    0                 0
# 3  I. kerület                  0                    0                 0
# 4  I. kerület                  0                    0                 0
# 5  I. kerület                  0                    0                 0
#
#    Chinese Restaurant  Comfort Food Restaurant  Dim Sum Restaurant  \
# 1                   0                        0                   0
# 2                   0                        0                   0
# 3                   0                        0                   0
# 4                   0                        0                   0
# 5                   0                        0                   0
#
#    Doner Restaurant  Dumpling Restaurant  Eastern European Restaurant  \
# ...

# %%
Budapest_onehot.shape
# Out:
# (257, 35)

# %%
Budapest_grouped = Budapest_onehot.groupby('District').mean().reset_index()
Budapest_grouped
# Out:
#           District  Afghan Restaurant  American Restaurant  Asian Restaurant  \
# 0              All           0.000000             0.000000          0.500000
# 1       I. kerület           0.000000             0.000000          0.000000
# 2     III. kerület           0.000000             0.050000          0.150000
# 3      IV. kerület           0.000000             0.000000          0.000000
# 4      IX. kerület           0.000000             0.000000          0.111111
# 5       V. kerület           0.000000             0.000000          0.055556
# 6      VI. kerület           0.000000             0.000000          0.058824
# 7     VII. kerület           0.000000             0.000000          0.055556
# 8    VIII. kerület           0.000000             0.000000          0.052632
# 9       X. kerület           0.000000             0.000000          0.000000
# 10     XI. kerület           0.066667             0.000000          0.000000
# ...

# %%
Budapest_grouped.shape
# Out:
# (22, 35)

# %%
num_top_venues = 10

for hood in Budapest_grouped['District']:
    print("----"+hood+"----")
    temp = Budapest_grouped[Budapest_grouped['District'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----All----
#                         venue  freq
# 0            Asian Restaurant   0.5
# 1    Mediterranean Restaurant   0.5
# 2           Afghan Restaurant   0.0
# 3          Seafood Restaurant   0.0
# 4   Middle Eastern Restaurant   0.0
# 5  Modern European Restaurant   0.0
# 6                  Restaurant   0.0
# 7          Russian Restaurant   0.0
# 8     Scandinavian Restaurant   0.0
# 9            Sushi Restaurant   0.0
#
#
# ----I. kerület----
#                       venue  freq
# 0        Italian Restaurant  0.31
# 1      Hungarian Restaurant  0.15
# 2     Vietnamese Restaurant  0.08
# 3         French Restaurant  0.08
# 4  Mediterranean Restaurant  0.08
# 5         Indian Restaurant  0.08
# 6        Russian Restaurant  0.08
# 7        Mexican Restaurant  0.08
# 8          Sushi Restaurant  0.08
# 9        Spanish Restaurant  0.00
#
#
# ----III. kerület----
#                          venue  freq
# 0                   Restaurant  0.25
# 1             Asian Restaurant  0.15
# ...

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['District']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

Budapest_venues_sorted = pd.DataFrame(columns=columns)
Budapest_venues_sorted['District'] = Budapest_grouped['District']

for ind in np.arange(Cologne_grouped.shape[0]):
    Budapest_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Budapest_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(23)
# Out:
#     Cluster Labels    Neighborhood        1st Most Common Venue  \
# 0                3             All     Mediterranean Restaurant
# 1                1      I. kerület           Italian Restaurant
# 2                0    III. kerület                   Restaurant
# 3                0     IV. kerület         Hungarian Restaurant
# 4                1     IX. kerület        Vietnamese Restaurant
# 5                0      V. kerület           Italian Restaurant
# 6                0     VI. kerület                   Restaurant
# 7                0    VII. kerület                   Restaurant
# 8                1   VIII. kerület        Vietnamese Restaurant
# 9                1      X. kerület         Hungarian Restaurant
# 10               1     XI. kerület        Vietnamese Restaurant
# 11               0    XII. kerület                   Restaurant
# 12               0   XIII. kerület            Indian Restaurant
# 13               1    XIV. kerület         Hungarian Restaurant
# ...

# %%
kclusters = 5

Budapest_grouped_clustering = Budapest_grouped.drop('District', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Budapest_grouped_clustering)

kmeans.labels_[0:10]
# Out:
# array([3, 1, 0, 0, 1, 0, 0, 0, 1, 1], dtype=int32)

# %%
Budapest_merged = df
Budapest_merged.head(10)
# Out:
#          District                                               Name  \
# 0      I. kerület                     Várkerület ("Castle District")
# 2    III. kerület         Óbuda-Békásmegyer ("Old Buda-Békásmegyer")
# 3     IV. kerület                                Újpest ("New Pest")
# 4      V. kerület  Belváros-Lipótváros ("Inner City - Leopold Town")
# 5     VI. kerület                        Terézváros ("Theresa Town")
# 6    VII. kerület                   Erzsébetváros ("Elisabeth Town")
# 7   VIII. kerület                        Józsefváros ("Joseph Town")
# 8     IX. kerület                       Ferencváros ("Francis Town")
# 9      X. kerület                                 Kőbánya ("Quarry")
# 10    XI. kerület                                Újbuda ("New Buda")
#
#      Latitude  Longitude
# 0   47.499163  19.035143
# 2   47.567611  19.036780
# 3   47.576169  19.095508
# 4   47.499945  19.050549
# 5   47.509494  19.065323
# 6   47.502200  19.075153
# ...

# %%
Budapest_venues_sorted.head(23)
# Out:
#           District        1st Most Common Venue        2nd Most Common Venue  \
# 0              All     Mediterranean Restaurant             Asian Restaurant
# 1       I. kerület           Italian Restaurant         Hungarian Restaurant
# 2     III. kerület                   Restaurant             Asian Restaurant
# 3      IV. kerület         Hungarian Restaurant                   Restaurant
# 4      IX. kerület        Vietnamese Restaurant             Asian Restaurant
# 5       V. kerület           Italian Restaurant                   Restaurant
# 6      VI. kerület                   Restaurant           Italian Restaurant
# 7     VII. kerület                   Restaurant           Italian Restaurant
# 8    VIII. kerület        Vietnamese Restaurant             Tapas Restaurant
# 9       X. kerület         Hungarian Restaurant        Vietnamese Restaurant
# 10     XI. kerület        Vietnamese Restaurant         Hungarian Restaurant
# ...

# %%
Budapest_venues_sorted_w_clusters = neighborhoods_venues_sorted

# %%
neighborhoods_venues_sorted_w_clusters.head(9)
# Out:
#    Cluster Labels   Neighborhood     1st Most Common Venue  \
# 0               3            All  Mediterranean Restaurant
# 1               1     I. kerület        Italian Restaurant
# 2               0   III. kerület                Restaurant
# 3               0    IV. kerület      Hungarian Restaurant
# 4               1    IX. kerület     Vietnamese Restaurant
# 5               0     V. kerület        Italian Restaurant
# 6               0    VI. kerület                Restaurant
# 7               0   VII. kerület                Restaurant
# 8               1  VIII. kerület     Vietnamese Restaurant
#
#   2nd Most Common Venue        3rd Most Common Venue  \
# 0      Asian Restaurant        Vietnamese Restaurant
# 1  Hungarian Restaurant        Vietnamese Restaurant
# 2      Asian Restaurant         Hungarian Restaurant
# 3            Restaurant  Eastern European Restaurant
# 4      Asian Restaurant           Chinese Restaurant
# ...

# %%
neighborhoods_venues_sorted_w_clusters.insert(0, 'Cluster Labels', kmeans.labels_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-329-e399f2fb2f7f> in <module>
# ----> 1 neighborhoods_venues_sorted_w_clusters.insert(0, 'Cluster Labels', kmeans.labels_)
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
# ...

# %%
neighborhoods_venues_sorted_w_clusters.head(23)
# Out:
#     Cluster Labels    Neighborhood        1st Most Common Venue  \
# 0                3             All     Mediterranean Restaurant
# 1                1      I. kerület           Italian Restaurant
# 2                0    III. kerület                   Restaurant
# 3                0     IV. kerület         Hungarian Restaurant
# 4                1     IX. kerület        Vietnamese Restaurant
# 5                0      V. kerület           Italian Restaurant
# 6                0     VI. kerület                   Restaurant
# 7                0    VII. kerület                   Restaurant
# 8                1   VIII. kerület        Vietnamese Restaurant
# 9                1      X. kerület         Hungarian Restaurant
# 10               1     XI. kerület        Vietnamese Restaurant
# 11               0    XII. kerület                   Restaurant
# 12               0   XIII. kerület            Indian Restaurant
# 13               1    XIV. kerület         Hungarian Restaurant
# ...

# %%
Budapest_merged.rename(columns={'District':'Neighborhood'}, inplace=True)

Budapest_merged = Budapest_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

Budapest_merged.head(10)
# Out:
#      Neighborhood                                               Name  \
# 0      I. kerület                     Várkerület ("Castle District")
# 2    III. kerület         Óbuda-Békásmegyer ("Old Buda-Békásmegyer")
# 3     IV. kerület                                Újpest ("New Pest")
# 4      V. kerület  Belváros-Lipótváros ("Inner City - Leopold Town")
# 5     VI. kerület                        Terézváros ("Theresa Town")
# 6    VII. kerület                   Erzsébetváros ("Elisabeth Town")
# 7   VIII. kerület                        Józsefváros ("Joseph Town")
# 8     IX. kerület                       Ferencváros ("Francis Town")
# 9      X. kerület                                 Kőbánya ("Quarry")
# 10    XI. kerület                                Újbuda ("New Buda")
#
#      Latitude  Longitude  Cluster Labels  1st Most Common Venue  \
# 0   47.499163  19.035143               1     Italian Restaurant
# 2   47.567611  19.036780               0             Restaurant
# ...

# %%
# create a map with folium
map_restaurants10 = folium.Map(location=[latitude,longitude], tiles='cartodbpositron', 
                               attr="<a href=https://github.com/python-visualization/folium/>Folium</a>")

# set color scheme for the five clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
for lat, lon, poi, cluster in zip(Cologne_merged['Latitude'], 
                                  Cologne_merged['Longitude'], 
                                  Cologne_merged['Neighborhood'], 
                                  Cologne_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=list_rest_no[list_dist.index(poi)]*0.5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_restaurants10)
       
map_restaurants10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 0, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                                  Name  \
# 2          Óbuda-Békásmegyer ("Old Buda-Békásmegyer")
# 3                                 Újpest ("New Pest")
# 4   Belváros-Lipótváros ("Inner City - Leopold Town")
# 5                         Terézváros ("Theresa Town")
# 6                    Erzsébetváros ("Elisabeth Town")
# 11                            Hegyvidék ("Highlands")
# 12  Angyalföld-Újlipótváros-Vizafogó ("Angel's Fie...
# 17  Pestszentlőrinc-Pestszentimre ("Saint Lawrence...
# 18                            Kispest ("Little Pest")
# 21                                     Budafok-Tétény
#
#           1st Most Common Venue        2nd Most Common Venue  \
# 2                    Restaurant             Asian Restaurant
# 3          Hungarian Restaurant                   Restaurant
# 4            Italian Restaurant                   Restaurant
# 5                    Restaurant           Italian Restaurant
# ...

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 1, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                               Name  1st Most Common Venue  \
# 0   Várkerület ("Castle District")     Italian Restaurant
# 7      Józsefváros ("Joseph Town")  Vietnamese Restaurant
# 8     Ferencváros ("Francis Town")  Vietnamese Restaurant
# 9               Kőbánya ("Quarry")   Hungarian Restaurant
# 10             Újbuda ("New Buda")  Vietnamese Restaurant
# 13                           Zugló   Hungarian Restaurant
#
#     2nd Most Common Venue  3rd Most Common Venue  \
# 0    Hungarian Restaurant  Vietnamese Restaurant
# 7        Tapas Restaurant     Italian Restaurant
# 8        Asian Restaurant     Chinese Restaurant
# 9   Vietnamese Restaurant       Sushi Restaurant
# 10   Hungarian Restaurant     Italian Restaurant
# 13     Italian Restaurant     Chinese Restaurant
#
#             4th Most Common Venue     5th Most Common Venue  \
# 0               French Restaurant  Mediterranean Restaurant
# 7                      Restaurant  Mediterranean Restaurant
# ...

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 2, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#                                   Name 1st Most Common Venue  \
# 14     Rákospalota-Pestújhely-Újpalota  Fast Food Restaurant
# 16                          Rákosmente            Restaurant
# 19  Pesterzsébet ("Elisabeth by Pest")            Restaurant
# 20                              Csepel            Restaurant
#
#    2nd Most Common Venue        3rd Most Common Venue  \
# 14            Restaurant      Comfort Food Restaurant
# 16  Hungarian Restaurant         Fast Food Restaurant
# 19  Fast Food Restaurant        Vietnamese Restaurant
# 20  Fast Food Restaurant  Eastern European Restaurant
#
#           4th Most Common Venue        5th Most Common Venue  \
# 14        Vietnamese Restaurant  Eastern European Restaurant
# 16        Vietnamese Restaurant  Eastern European Restaurant
# 19  Eastern European Restaurant         Hungarian Restaurant
# 20           Chinese Restaurant             Sushi Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# ...

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 3, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#         Name     1st Most Common Venue 2nd Most Common Venue  \
# 23  Budapest  Mediterranean Restaurant      Asian Restaurant
#
#     3rd Most Common Venue        4th Most Common Venue 5th Most Common Venue  \
# 23  Vietnamese Restaurant  Eastern European Restaurant  Hungarian Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 23      Greek Restaurant     French Restaurant  Fast Food Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 23    Falafel Restaurant    Dumpling Restaurant

# %%
Cologne_merged.loc[Cologne_merged['Cluster Labels'] == 4, Cologne_merged.columns[[1] + list(range(5, Cologne_merged.shape[1]))]]
# Out:
#         Name    1st Most Common Venue 2nd Most Common Venue  \
# 22  Soroksár  Scandinavian Restaurant  Hungarian Restaurant
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 22  Vietnamese Restaurant      Greek Restaurant     French Restaurant
#
#    6th Most Common Venue 7th Most Common Venue        8th Most Common Venue  \
# 22  Fast Food Restaurant    Falafel Restaurant  Eastern European Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 22   Dumpling Restaurant     Italian Restaurant
